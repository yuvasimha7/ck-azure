# %%
import os
import io
import requests
import pandas as pd
from datetime import timedelta
from datetime import datetime as dt
import time
from io import StringIO
import requests
from datetime import datetime as dt, timedelta
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

# %%
import os
import io
import requests
import pandas as pd
from datetime import timedelta
from datetime import datetime as dt
import time
from io import StringIO
import requests
from datetime import datetime as dt

import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

def CME(access_token, table_name, code):
    base_url = "https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements"
    end_date = dt.today()  # Get the current date
    start_date = end_date - timedelta(days=7)  # Calculate the start date

    data_frames = []  # List to store DataFrames for each day
    print(end_date)
    while start_date <= end_date:
        date_str = start_date.strftime("%m/%d/%Y")  # Format date as "MM/DD/YYYY"
        print(date_str)
        url = f"{base_url}/{code}/FUT"
        print(url)
        params = {
            "strategy": "DEFAULT",
            "tradeDate": date_str,
            "pageSize": "500"
        }

        headers = {
            "accept": "application/json, text/plain, */*"
        }
        
        response = requests.get(url, params=params, headers=headers)
        print(response.status_code)

        data = response.json()
        settlements = data.get("settlements", [])

        df = pd.DataFrame(settlements)
        df['date'] = start_date.strftime("%d-%b-%Y")  # Format date as "DD-MM-YYYY"
        data_frames.append(df)
        print(start_date) #remove this later
        start_date =start_date+ timedelta(days=1)  # Move to the next day

    # Concatenate all DataFrames into a single DataFrame
    result_df = pd.concat(data_frames, ignore_index=True)
    print(result_df.columns)
    print(result_df)

# %%
CME('access_token', 'CME_German_Power', 8381) 
#CME('access_token', 'CME_Soyabean', 312) 
#CME('access_token', 'CME_Ethanol', 338)
# Out:
# 2023-12-15 15:24:35.041246
# 12/08/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-08 15:24:35.041246
# 12/09/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-09 15:24:35.041246
# 12/10/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-10 15:24:35.041246
# 12/11/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-11 15:24:35.041246
# 12/12/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-12 15:24:35.041246
# 12/13/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-13 15:24:35.041246
# 12/14/2023
# https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT
# 200
# 2023-12-14 15:24:35.041246
# 12/15/2023
# ...

# %%
result_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result_df
#
# NameError: name 'result_df' is not defined

# %%
import os
import io
import requests
import pandas as pd
from datetime import timedelta, datetime as dt  # Import datetime as dt
import time
from io import StringIO
import requests
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

def CME(access_token, table_name, code):
    base_url = "https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements"
    end_date = dt.date.today()  # Use dt.date.today() to access the current date
    start_date = end_date - dt.timedelta(days=7)  # Use dt.timedelta to calculate the start date

    data_frames = []  # List to store DataFrames for each day

    while start_date <= end_date:
        date_str = start_date.strftime("%m/%d/%Y")  # Format date as "MM/DD/YYYY"
        url = f"{base_url}/{code}/FUT"
        params = {
            "strategy": "DEFAULT",
            "tradeDate": date_str,
            "pageSize": "500"
        }

        headers = {
            "accept": "application/json, text/plain, */*"
        }

        response = requests.get(url, params=params, headers=headers)
        print(response.status_code)

        data = response.json()
        settlements = data.get("settlements", [])

        df = pd.DataFrame(settlements)
        df['date'] = start_date.strftime("%d-%b-%Y")  # Format date as "DD-MM-YYYY"
        data_frames.append(df)

        start_date += dt.timedelta(days=1)  # Use dt.timedelta to move to the next day

    # Concatenate all DataFrames into a single DataFrame
    result_df = pd.concat(data_frames, ignore_index=True)
    
CME('access_token', 'CME_German_Power', 8381)

# %%
import requests
import pandas as pd
url = "https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT?strategy=DEFAULT&tradeDate=11/07/2023&pageSize=500&isProtected&_t=1699428945564"

# Define a custom user-agent string
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

# Send an HTTP GET request to the URL with the custom user-agent header
response = requests.get(url, headers=headers)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Extract the "settlements" data
    settlements = data.get("settlements", [])

    # Create a DataFrame
    df = pd.DataFrame(settlements)

    # Rename columns as needed
    df.rename(columns={
        "month": "Month",
        "open": "Open",
        "high": "High",
        "low": "Low",
        "last": "Last",
        "change": "Change",
        "settle": "Settle",
        "volume": "Volume",
        "openInterest": "Open Interest"
    }, inplace=True)

    # Display the DataFrame
    print(df)
else:
    print(f"Request failed with status code {response.status_code}")

# Close the response
response.close()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd

url = "https://www.cmegroup.com/CmeWS/mvc/Settlements/Futures/Settlements/8381/FUT?strategy=DEFAULT&tradeDate=11/07/2023&pageSize=500&isProtected&_t=1699428945564"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Extract the "settlements" data
    settlements = data.get("settlements", [])

    # Create a DataFrame
    df = pd.DataFrame(settlements)

    # Rename columns as needed
    df.rename(columns={
        "month": "Month",
        "open": "Open",
        "high": "High",
        "low": "Low",
        "last": "Last",
        "change": "Change",
        "settle": "Settle",
        "volume": "Volume",
        "openInterest": "Open Interest"
    }, inplace=True)

    # Display the DataFrame
    print(df)
else:
    print(f"Request failed with status code {response.status_code}")

# Close the response
response.close()

# %%
def CME(access_token, table_name, code):
    current_datetime = dt.now()
    
    # Convert the current date and time to a Unix timestamp in milliseconds
    unix_timestamp = int(current_datetime.timestamp() * 1000) 
    
    # URL with the dynamically generated Unix timestamp
    url = f"https://www.cmegroup.com/CmeWS/mvc/Quotes/Future/{code}/G?isProtected&_t={unix_timestamp}"
    
    # Define the custom User-Agent
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
    
    # Set the User-Agent header in the headers dictionary
    headers = {
        "User-Agent": user_agent
    }
    
    # Make the GET request with the custom User-Agent
    response = requests.get(url, headers=headers)
    
    data = json.loads(response.text)
    date = data["tradeDate"]
    quotes = data["quotes"]
    df = pd.DataFrame(quotes, columns=["expirationMonth", "quoteCode", "last", "change", "priorSettle", "open", "close", "high", "low", "highLimit", "lowLimit", "volume", "percentageChange", "expirationMonth", "quoteCode"])
    df['date'] = date
    print(df)
    df.to_csv(r'D:\CME_German_power.csv')
    #push_data2(commit_table[table_name], df, access_token)

# %%
CME('access_token','fe',8381)
# Out:
#    expirationMonth quoteCode last change priorSettle open close high low  \
# 0         DEC 2023     DEBZ3    -      -       74.23    -     -    -   -
# 1         JAN 2024     DEBF4    -      -       85.56    -     -    -   -
# 2         FEB 2024     DEBG4    -      -       91.47    -     -    -   -
# 3         MAR 2024     DEBH4    -      -       84.58    -     -    -   -
# 4         APR 2024     DEBJ4    -      -       78.96    -     -    -   -
# 5         MAY 2024     DEBK4    -      -       73.07    -     -    -   -
# 6         JUN 2024     DEBM4    -      -       80.18    -     -    -   -
# 7         JUL 2024     DEBN4    -      -       87.85    -     -    -   -
# 8         AUG 2024     DEBQ4    -      -       84.86    -     -    -   -
# 9         SEP 2024     DEBU4    -      -       99.15    -     -    -   -
# 10        OCT 2024     DEBV4    -      -      105.13    -     -    -   -
# 11        NOV 2024     DEBX4    -      -      105.13    -     -    -   -
# ...
